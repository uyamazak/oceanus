# %%
2**10
# Out:
# 1024

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3]
y = [2, 4, 6]
plt.plot(x, y)
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from pprint import pprint
from bigquery import get_client
JSON_KEY_FILE = "Oceanus-dev-784c5c9ec4b7.json"
bq = get_client(json_key_file=JSON_KEY_FILE, readonly=True)

job_id, results = bq.query("""
SELECT o.uid, o.sid, o.evt, o.dev, o.jsn, b.employee_scale_id, b.company_prefecture_id, b.gender
    FROM [oceanus-dev:oceanus_prod.oceanus_v3_bizocean_20160904] as o
    JOIN [oceanus-dev:temp_tables.bizocean_member_20160905] as b
        ON o.uid = b.member_id
WHERE evt == "emailopen" OR evt == "emailclick" 
LIMIT 100
""", timeout=100)


print(job_id)
pprint(results)
# Out:
# job_qvnQWbYAW970suDyaIm4-rE0cvY
# [{'b_company_prefecture_id': 1,
#   'b_employee_scale_id': 0,
#   'b_gender': 'male',
#   'o_dev': 'tablet',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2978',
#   'o_uid': '2978'},
#  {'b_company_prefecture_id': 1,
#   'b_employee_scale_id': 0,
#   'b_gender': 'male',
#   'o_dev': 'tablet',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2978',
#   'o_uid': '2978'},
#  {'b_company_prefecture_id': 34,
#   'b_employee_scale_id': 0,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '540',
#   'o_uid': '540'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'tablet',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '836506',
#   'o_uid': '836506'},
#  {'b_company_prefecture_id': 27,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "55", "aiid": "6"}',
#   'o_sid': '1308926',
#   'o_uid': '1308926'},
#  {'b_company_prefecture_id': 27,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '1308926',
#   'o_uid': '1308926'},
#  {'b_company_prefecture_id': 8,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '1676710',
#   'o_uid': '1676710'},
#  {'b_company_prefecture_id': 26,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '1750358',
#   'o_uid': '1750358'},
#  {'b_company_prefecture_id': 24,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'tablet',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '1752005',
#   'o_uid': '1752005'},
#  {'b_company_prefecture_id': 11,
#   'b_employee_scale_id': 3,
#   'b_gender': 'male',
#   'o_dev': 'tablet',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '1754742',
#   'o_uid': '1754742'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'female',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '1988090',
#   'o_uid': '1988090'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'female',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '1988090',
#   'o_uid': '1988090'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 3,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '2058011',
#   'o_uid': '2058011'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 3,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2058011',
#   'o_uid': '2058011'},
#  {'b_company_prefecture_id': 21,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2083685',
#   'o_uid': '2083685'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '2150417',
#   'o_uid': '2150417'},
#  {'b_company_prefecture_id': 11,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '2192889',
#   'o_uid': '2192889'},
#  {'b_company_prefecture_id': 11,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2192889',
#   'o_uid': '2192889'},
#  {'b_company_prefecture_id': 27,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '2323551',
#   'o_uid': '2323551'},
#  {'b_company_prefecture_id': 18,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'tablet',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2463715',
#   'o_uid': '2463715'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '2472155',
#   'o_uid': '2472155'},
#  {'b_company_prefecture_id': 23,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "55", "aiid": "6"}',
#   'o_sid': '2521197',
#   'o_uid': '2521197'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 3,
#   'b_gender': 'male',
#   'o_dev': '',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2606749',
#   'o_uid': '2606749'},
#  {'b_company_prefecture_id': 19,
#   'b_employee_scale_id': 1,
#   'b_gender': 'female',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '2894488',
#   'o_uid': '2894488'},
#  {'b_company_prefecture_id': 1,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '3000672',
#   'o_uid': '3000672'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '3027418',
#   'o_uid': '3027418'},
#  {'b_company_prefecture_id': 14,
#   'b_employee_scale_id': 4,
#   'b_gender': 'male',
#   'o_dev': 'tablet',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '475813',
#   'o_uid': '475813'},
#  {'b_company_prefecture_id': 14,
#   'b_employee_scale_id': 4,
#   'b_gender': 'male',
#   'o_dev': 'tablet',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '475813',
#   'o_uid': '475813'},
#  {'b_company_prefecture_id': 14,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '1629775',
#   'o_uid': '1629775'},
#  {'b_company_prefecture_id': 14,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '1629775',
#   'o_uid': '1629775'},
#  {'b_company_prefecture_id': 14,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '1629775',
#   'o_uid': '1629775'},
#  {'b_company_prefecture_id': 14,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '1629775',
#   'o_uid': '1629775'},
#  {'b_company_prefecture_id': 14,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '1629775',
#   'o_uid': '1629775'},
#  {'b_company_prefecture_id': 14,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '1639586',
#   'o_uid': '1639586'},
#  {'b_company_prefecture_id': 14,
#   'b_employee_scale_id': 2,
#   'b_gender': 'female',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '1641037',
#   'o_uid': '1641037'},
#  {'b_company_prefecture_id': 15,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '1956956',
#   'o_uid': '1956956'},
#  {'b_company_prefecture_id': 1,
#   'b_employee_scale_id': 3,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '2086160',
#   'o_uid': '2086160'},
#  {'b_company_prefecture_id': 1,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '2341236',
#   'o_uid': '2341236'},
#  {'b_company_prefecture_id': 1,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '2341236',
#   'o_uid': '2341236'},
#  {'b_company_prefecture_id': 1,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2341236',
#   'o_uid': '2341236'},
#  {'b_company_prefecture_id': 10,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2587976',
#   'o_uid': '2587976'},
#  {'b_company_prefecture_id': 10,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '2587976',
#   'o_uid': '2587976'},
#  {'b_company_prefecture_id': 10,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2587976',
#   'o_uid': '2587976'},
#  {'b_company_prefecture_id': 36,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2619089',
#   'o_uid': '2619089'},
#  {'b_company_prefecture_id': 23,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "53", "aiid": "2"}',
#   'o_sid': '2791615',
#   'o_uid': '2791615'},
#  {'b_company_prefecture_id': 23,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '2791615',
#   'o_uid': '2791615'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 3,
#   'b_gender': 'other',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2894643',
#   'o_uid': '2894643'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'female',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2960205',
#   'o_uid': '2960205'},
#  {'b_company_prefecture_id': 47,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'tablet',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '3039605',
#   'o_uid': '3039605'},
#  {'b_company_prefecture_id': 21,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '3075192',
#   'o_uid': '3075192'},
#  {'b_company_prefecture_id': 27,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '939753',
#   'o_uid': '939753'},
#  {'b_company_prefecture_id': 23,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "55", "aiid": "6"}',
#   'o_sid': '1267291',
#   'o_uid': '1267291'},
#  {'b_company_prefecture_id': 39,
#   'b_employee_scale_id': 4,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '1341190',
#   'o_uid': '1341190'},
#  {'b_company_prefecture_id': 27,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '1812564',
#   'o_uid': '1812564'},
#  {'b_company_prefecture_id': 27,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "55", "aiid": "6"}',
#   'o_sid': '1812564',
#   'o_uid': '1812564'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '2155945',
#   'o_uid': '2155945'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '2327686',
#   'o_uid': '2327686'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '2459751',
#   'o_uid': '2459751'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2459751',
#   'o_uid': '2459751'},
#  {'b_company_prefecture_id': 28,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2890853',
#   'o_uid': '2890853'},
#  {'b_company_prefecture_id': 1,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '2955301',
#   'o_uid': '2955301'},
#  {'b_company_prefecture_id': 1,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '2955301',
#   'o_uid': '2955301'},
#  {'b_company_prefecture_id': 1,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '2955301',
#   'o_uid': '2955301'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2971864',
#   'o_uid': '2971864'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '2971864',
#   'o_uid': '2971864'},
#  {'b_company_prefecture_id': 14,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '617869',
#   'o_uid': '617869'},
#  {'b_company_prefecture_id': 37,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '674778',
#   'o_uid': '674778'},
#  {'b_company_prefecture_id': 37,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '674778',
#   'o_uid': '674778'},
#  {'b_company_prefecture_id': 1,
#   'b_employee_scale_id': 4,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '695541',
#   'o_uid': '695541'},
#  {'b_company_prefecture_id': 1,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '912006',
#   'o_uid': '912006'},
#  {'b_company_prefecture_id': 28,
#   'b_employee_scale_id': 3,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '1092533',
#   'o_uid': '1092533'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 4,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '1160402',
#   'o_uid': '1160402'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 4,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '1160402',
#   'o_uid': '1160402'},
#  {'b_company_prefecture_id': 11,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '1286763',
#   'o_uid': '1286763'},
#  {'b_company_prefecture_id': 28,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '1322804',
#   'o_uid': '1322804'},
#  {'b_company_prefecture_id': 14,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '1364999',
#   'o_uid': '1364999'},
#  {'b_company_prefecture_id': 14,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '1364999',
#   'o_uid': '1364999'},
#  {'b_company_prefecture_id': 4,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': '',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '1399713',
#   'o_uid': '1399713'},
#  {'b_company_prefecture_id': 4,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': '',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '1399713',
#   'o_uid': '1399713'},
#  {'b_company_prefecture_id': 4,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': '',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '1399713',
#   'o_uid': '1399713'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'tablet',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '1625852',
#   'o_uid': '1625852'},
#  {'b_company_prefecture_id': 27,
#   'b_employee_scale_id': 2,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '1735294',
#   'o_uid': '1735294'},
#  {'b_company_prefecture_id': 11,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '1864871',
#   'o_uid': '1864871'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2230859',
#   'o_uid': '2230859'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2286182',
#   'o_uid': '2286182'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2286182',
#   'o_uid': '2286182'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2286182',
#   'o_uid': '2286182'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2286182',
#   'o_uid': '2286182'},
#  {'b_company_prefecture_id': 23,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "55", "aiid": "6"}',
#   'o_sid': '2331913',
#   'o_uid': '2331913'},
#  {'b_company_prefecture_id': 34,
#   'b_employee_scale_id': 2,
#   'b_gender': 'female',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2373573',
#   'o_uid': '2373573'},
#  {'b_company_prefecture_id': 27,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '2390263',
#   'o_uid': '2390263'},
#  {'b_company_prefecture_id': 27,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "39", "aiid": "1"}',
#   'o_sid': '2390263',
#   'o_uid': '2390263'},
#  {'b_company_prefecture_id': 27,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2566159',
#   'o_uid': '2566159'},
#  {'b_company_prefecture_id': 27,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2566159',
#   'o_uid': '2566159'},
#  {'b_company_prefecture_id': 23,
#   'b_employee_scale_id': 2,
#   'b_gender': 'female',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '2833664',
#   'o_uid': '2833664'},
#  {'b_company_prefecture_id': 28,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'mobile',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "54", "aiid": "25"}',
#   'o_sid': '2866017',
#   'o_uid': '2866017'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '2959787',
#   'o_uid': '2959787'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '550752',
#   'o_uid': '550752'},
#  {'b_company_prefecture_id': 21,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '1601406',
#   'o_uid': '1601406'},
#  {'b_company_prefecture_id': 13,
#   'b_employee_scale_id': 1,
#   'b_gender': 'male',
#   'o_dev': 'pc',
#   'o_evt': 'emailopen',
#   'o_jsn': '{"acid": "52", "aiid": "25"}',
#   'o_sid': '1669364',
#   'o_uid': '1669364'}]

# %%
from pprint import pprint
from bigquery import get_client
import pandas as pd

JSON_KEY_FILE = "Oceanus-dev-784c5c9ec4b7.json"
bq = get_client(json_key_file=JSON_KEY_FILE, readonly=True)

job_id, results = bq.query("""
SELECT 
    b.prefecture,
    CASE
      WHEN o.dev ="" THEN "other"
      ELSE o.dev
    END as dev,
    COUNT(*) as count,
FROM [oceanus-dev:oceanus_prod.oceanus_v3_bizocean_20160904] as o
    JOIN [oceanus-dev:temp_tables.member_20160905] as b
        ON o.uid = b.member_id
    WHERE o.evt == "emailopen" 
    GROUP BY b.prefecture, dev
    ORDER BY dev ASC , count  DESC
LIMIT 1000
""", timeout=100)

df = pd.DataFrame(results)
